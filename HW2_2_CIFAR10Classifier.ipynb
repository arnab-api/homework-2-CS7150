# %% [markdown]
# This can be run [run on Google Colab using this link](https://colab.research.google.com/github/CS7150/CS7150-Homework-2/blob/main/HW2_2_CIFAR10Classifier.ipynb)
#
# <font size='6'>**Homework 2.2: Neural Network CIFAR-10 Classification**</font>

# %% [markdown]
# <font size='5'>**Overview**</font>
#
# In this CS7150 assignment, our objective is to build a neural network featuring two fully-connected layers designed for classification purposes. We will evaluate the performance of this neural network by testing it on the CIFAR-10 dataset.
#
# This assignment adheres to a standard classification setup, which encompasses the use of a dataloader to load labeled image data in a natural form and training the model in a minibatch-based fashion.
#
# **Your assignment**: Your responsibility throughout this notebook is to thoroughly review the content and address all the conceptual and technical questions identified within the sections marked with "Task" headers and "TODO:" comments in the code.

# %% [markdown]
# <font size='5'>**I) Setup**</font>

# %%
import os
import torch
from torch import nn
from torchvision.datasets import CIFAR10
from torchvision.transforms import Compose, ToTensor
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %% [markdown]
# <font size='4'>**Device Setup**</font>

# %% [markdown]
# We aim to enable model training on a GPU to expedite our computations. First, we'll check whether torch.cuda is accessible; if it is, we will utilize the GPU; otherwise, we will continue to using the CPU.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# <font size='4'>**Loading CIFAR-10 Data**</font>

# %% [markdown]
# The CIFAR-10 dataset comprises a collection of 60,000 32x32 color images distributed across ten distinct classes. These classes correspond to various objects and include airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. Within each class, there are precisely 6,000 images.

# %%
# downloading cifar10 into folder
data_dir = 'cifar10_data' # make sure that this folder is created in your working dir

#TODO: Fill out train_data and test_data variables using CIFAR10 (i.e., torchvision.datasets.CIFAR)
train_data = CIFAR10(data_dir, train=True, download=True, transform=Compose([ToTensor()]))
test_data = CIFAR10(data_dir, train=False, download=True, transform=Compose([ToTensor()]))
#train_data = None
#test_data = None
print(f'Datatype of the dataset object: {type(train_data)}')
# check the length of dataset
print(f'Number of samples in training data: {len(train_data)}')
print(f'Number of samples in test data: {len(test_data)}')
# Check the format of dataset
print(f'Format of the dataset: \n {train_data}')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar10_data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting cifar10_data/cifar-10-python.tar.gz to cifar10_data
# Files already downloaded and verified
# Datatype of the dataset object: <class 'torchvision.datasets.cifar.CIFAR10'>
# Number of samples in training data: 50000
# Number of samples in test data: 10000
# Format of the dataset:
#  Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: cifar10_data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %% [markdown]
# ### <font size='4'>**Displaying Loaded Dataset**</font>

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2, 3, i+1)
  plt.tight_layout()
  plt.imshow(train_data[i][0][0], cmap='gray', interpolation='none')
  plt.title("Class Label: {}".format(train_data[i][1]))
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ## <font size='5'>**II) Building a Neural Network**</font>

# %% [markdown]
# ### <font size='4'>**1) Defining `CIFAR10Classifier` class**</font>

# %% [markdown]
# <font size='4' color='Red'>Task 1.1 - Defining `CIFAR10Classifier` class (4 points)</font>
#
# In the following class, make adjustments to the following attributes: flatten, hidden_size, class_size, and linear_relu_stack. Ensure that the linear_relu_stack consists of a minimum of two linear layers combined with a non-linear activation layer.

# %%
class_labels = [sample[1] for sample in train_data]
len(set(class_labels))
# Out:
# 10

# %%
train_data[0][0].flatten().shape
# Out:
# torch.Size([3072])

# %%
class CIFAR10Classifier(nn.Module):
    def __init__(self):
        super(CIFAR10Classifier, self).__init__()
        ########################################################################
        # TODO: Complete the following variables as instructed earlier
        ########################################################################
        self.flatten = nn.Flatten()
        self.hidden_size = 2**11
        self.class_size = 10
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(train_data[0][0].flatten().shape[0], self.hidden_size), nn.ReLU(),
            nn.Linear(self.hidden_size, self.hidden_size), nn.ReLU(),
            # nn.Linear(self.hidden_size, self.hidden_size), nn.ReLU(),
            nn.Linear(self.hidden_size, self.class_size)
        )
        ########################################################################
        #                             END OF YOUR CODE                         #
        ########################################################################

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %% [markdown]
# ### <font size='4'>**2) Training a Neural Network**</font>

# %% [markdown]
# <font size='4' color='Red'>Task 1.2 - Defining parameters (3 points)</font>

# %% [markdown]
# Let's create an instance of `CIFAR10Classifier` and move it to the device. After doing so, we define the following hyperparameters for training:
#
# - **Number of Epochs**: This signifies the number of iterations over the dataset.
# - **Batch Size**: It represents the number of data samples that propagate through the network before parameter updates.
# - **Learning Rate**: This parameter determines the extent of model parameter updates during each batch/epoch. Smaller values lead to slower learning, while larger values may introduce instability during training.
#
# **Your Task**:
#
# 1. Set `learning_rate` to 1e-3, `batch_size` to 64, and `epochs` to 10 initially. Experiment with different values and retain the final choices that yield the highest testing accuracy.
#
# 2. Select an appropriate loss function. You should experiment with different options, such as `CrossEntropyLoss()`, `MSELoss()`, and any others, and choose the one that best suits the task.
#
# 3. Define the `optimizer` variable using any optimizer function (e.g., SGD, Adam, etc.). Be sure to explore different parameter values within the chosen optimizer function.
#
# 4. Remember to record your ultimate choices for each variable that contribute to achieving the best performance for your `CIFAR10Classifier`. To receive full credit for this assignment, your model should attain a classification accuracy of over 50% on the test set.

# %%
model = CIFAR10Classifier().to(device)
model.requires_grad_(True)

########################################################################
# TODO: Complete the following variables as instructed earlier
########################################################################

learning_rate = 1e-3
batch_size = 64
epochs = 20
momentum = 0.9
weight_decay = 1e-3

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(
    model.parameters(), 
    lr=learning_rate, 
    weight_decay=weight_decay,
    momentum=momentum
)

########################################################################
#                             END OF YOUR CODE                         #
########################################################################

# %% [markdown]
# ### <font size='4'>**3) Train Loop**</font>

# %%
train_dataloader = DataLoader(train_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# In the above cell, we used a Dataloader to create batches for training and testing data. For each batch of size indicated in the batch_size hyperparameter, we perform backprop and update the model parameters' weights and biases.
#
# In the following cell, we define our train_loop.

# %%
def train_loop(dataloader, model, loss_fn, optimizer, print_log=True):
    size = len(dataloader.dataset)
    correct = 0
    training_acc = 0
    training_loss = 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X.to(device))
        loss = loss_fn(pred, y.to(device))
        correct += (pred.argmax(1) == y.to(device)).type(torch.float).sum().item()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss, current = loss.item(), batch * len(X)
        training_loss = loss
        if (print_log==True) and (batch % 100 == 0):
            print(f"""Training loop: loss: {loss:>7f}  [{current:>5d}/{size:>5d}]""")
    
    correct /= size
    training_acc = 100*correct
    if (print_log==True):
        print(f"""Training Accuracy: {training_acc:>0.1f}%""")
    return training_acc, training_loss

# %% [markdown]
# ### <font size='4'>**4) Test Loop**</font>

# %% [markdown]
# In the test loop, we iterate over the test dataset to check if model performance is improving.

# %%
def test_loop(dataloader, model, loss_fn, print_log=True):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X.to(device))
            test_loss += loss_fn(pred, y.to(device)).item()
            correct += (pred.argmax(1) == y.to(device)).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    testing_acc = 100*correct
    if (print_log==True):
        print(f"Testing Accuracy: {testing_acc:>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return testing_acc, test_loss

# %% [markdown]
# ### <font size='4'>**5) Running the loops**</font>

# %% [markdown]
# We run our loops for a certain number of times, which is indicated in the 'epoch' hyperparameter that we defined earlier. In the following cell, we run both our training and testing loop to see how our training and testing accuracies change over time.

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loop: loss: 2.310278  [    0/50000]
# Training loop: loss: 2.266635  [ 6400/50000]
# Training loop: loss: 2.130730  [12800/50000]
# Training loop: loss: 2.163909  [19200/50000]
# Training loop: loss: 2.035326  [25600/50000]
# Training loop: loss: 2.013878  [32000/50000]
# Training loop: loss: 2.122523  [38400/50000]
# Training loop: loss: 1.917112  [44800/50000]
# Training Accuracy: 25.8%
# Testing Accuracy: 31.3%, Avg loss: 1.923095
#
# Epoch 2
# -------------------------------
# Training loop: loss: 1.999293  [    0/50000]
# Training loop: loss: 1.962404  [ 6400/50000]
# Training loop: loss: 1.704637  [12800/50000]
# Training loop: loss: 1.946953  [19200/50000]
# Training loop: loss: 1.938552  [25600/50000]
# Training loop: loss: 1.918465  [32000/50000]
# Training loop: loss: 1.966671  [38400/50000]
# Training loop: loss: 1.779724  [44800/50000]
# Training Accuracy: 34.3%
# Testing Accuracy: 36.0%, Avg loss: 1.813709
#
# Epoch 3
# -------------------------------
# Training loop: loss: 1.831730  [    0/50000]
# Training loop: loss: 1.816124  [ 6400/50000]
# Training loop: loss: 1.568994  [12800/50000]
# Training loop: loss: 1.829947  [19200/50000]
# Training loop: loss: 1.847415  [25600/50000]
# Training loop: loss: 1.849271  [32000/50000]
# Training loop: loss: 1.885628  [38400/50000]
# Training loop: loss: 1.697226  [44800/50000]
# Training Accuracy: 37.2%
# Testing Accuracy: 38.3%, Avg loss: 1.745367
#
# Epoch 4
# -------------------------------
# Training loop: loss: 1.747348  [    0/50000]
# Training loop: loss: 1.714923  [ 6400/50000]
# Training loop: loss: 1.489278  [12800/50000]
# Training loop: loss: 1.766292  [19200/50000]
# Training loop: loss: 1.761025  [25600/50000]
# Training loop: loss: 1.810817  [32000/50000]
# Training loop: loss: 1.813434  [38400/50000]
# Training loop: loss: 1.643635  [44800/50000]
# Training Accuracy: 39.5%
# Testing Accuracy: 40.2%, Avg loss: 1.687037
#
# Epoch 5
# -------------------------------
# Training loop: loss: 1.685939  [    0/50000]
# Training loop: loss: 1.654012  [ 6400/50000]
# Training loop: loss: 1.432546  [12800/50000]
# Training loop: loss: 1.732412  [19200/50000]
# Training loop: loss: 1.699702  [25600/50000]
# Training loop: loss: 1.777268  [32000/50000]
# Training loop: loss: 1.765468  [38400/50000]
# Training loop: loss: 1.600460  [44800/50000]
# Training Accuracy: 41.4%
# Testing Accuracy: 42.3%, Avg loss: 1.635327
#
# Epoch 6
# -------------------------------
# Training loop: loss: 1.640104  [    0/50000]
# Training loop: loss: 1.613639  [ 6400/50000]
# Training loop: loss: 1.389576  [12800/50000]
# Training loop: loss: 1.708874  [19200/50000]
# Training loop: loss: 1.655959  [25600/50000]
# Training loop: loss: 1.737528  [32000/50000]
# Training loop: loss: 1.729378  [38400/50000]
# Training loop: loss: 1.565778  [44800/50000]
# Training Accuracy: 42.9%
# Testing Accuracy: 44.0%, Avg loss: 1.594731
#
# Epoch 7
# -------------------------------
# Training loop: loss: 1.604854  [    0/50000]
# Training loop: loss: 1.584428  [ 6400/50000]
# Training loop: loss: 1.357689  [12800/50000]
# Training loop: loss: 1.692494  [19200/50000]
# Training loop: loss: 1.620910  [25600/50000]
# Training loop: loss: 1.696043  [32000/50000]
# Training loop: loss: 1.703432  [38400/50000]
# Training loop: loss: 1.538229  [44800/50000]
# Training Accuracy: 44.3%
# Testing Accuracy: 44.9%, Avg loss: 1.563749
#
# Epoch 8
# -------------------------------
# Training loop: loss: 1.576276  [    0/50000]
# Training loop: loss: 1.567380  [ 6400/50000]
# Training loop: loss: 1.332783  [12800/50000]
# Training loop: loss: 1.667753  [19200/50000]
# Training loop: loss: 1.588781  [25600/50000]
# Training loop: loss: 1.661006  [32000/50000]
# Training loop: loss: 1.684912  [38400/50000]
# Training loop: loss: 1.515120  [44800/50000]
# Training Accuracy: 45.5%
# Testing Accuracy: 45.7%, Avg loss: 1.538983
#
# Epoch 9
# -------------------------------
# Training loop: loss: 1.551197  [    0/50000]
# Training loop: loss: 1.548045  [ 6400/50000]
# Training loop: loss: 1.305570  [12800/50000]
# Training loop: loss: 1.643795  [19200/50000]
# Training loop: loss: 1.561122  [25600/50000]
# Training loop: loss: 1.629358  [32000/50000]
# Training loop: loss: 1.669409  [38400/50000]
# Training loop: loss: 1.493824  [44800/50000]
# Training Accuracy: 46.6%
# Testing Accuracy: 46.5%, Avg loss: 1.518759
#
# Epoch 10
# -------------------------------
# Training loop: loss: 1.528165  [    0/50000]
# Training loop: loss: 1.528079  [ 6400/50000]
# Training loop: loss: 1.281615  [12800/50000]
# Training loop: loss: 1.615774  [19200/50000]
# Training loop: loss: 1.535055  [25600/50000]
# Training loop: loss: 1.601210  [32000/50000]
# Training loop: loss: 1.653674  [38400/50000]
# Training loop: loss: 1.473206  [44800/50000]
# Training Accuracy: 47.5%
# Testing Accuracy: 47.1%, Avg loss: 1.500318
#
# Epoch 11
# -------------------------------
# Training loop: loss: 1.502625  [    0/50000]
# Training loop: loss: 1.508638  [ 6400/50000]
# Training loop: loss: 1.263786  [12800/50000]
# Training loop: loss: 1.588728  [19200/50000]
# Training loop: loss: 1.509629  [25600/50000]
# Training loop: loss: 1.577763  [32000/50000]
# Training loop: loss: 1.636238  [38400/50000]
# Training loop: loss: 1.455058  [44800/50000]
# Training Accuracy: 48.4%
# Testing Accuracy: 47.7%, Avg loss: 1.482353
#
# Epoch 12
# -------------------------------
# Training loop: loss: 1.478393  [    0/50000]
# Training loop: loss: 1.488649  [ 6400/50000]
# Training loop: loss: 1.245571  [12800/50000]
# Training loop: loss: 1.561370  [19200/50000]
# Training loop: loss: 1.486681  [25600/50000]
# Training loop: loss: 1.553960  [32000/50000]
# Training loop: loss: 1.618539  [38400/50000]
# Training loop: loss: 1.440244  [44800/50000]
# Training Accuracy: 49.3%
# Testing Accuracy: 48.4%, Avg loss: 1.466281
#
# Epoch 13
# -------------------------------
# Training loop: loss: 1.456959  [    0/50000]
# Training loop: loss: 1.462064  [ 6400/50000]
# Training loop: loss: 1.233470  [12800/50000]
# Training loop: loss: 1.539525  [19200/50000]
# Training loop: loss: 1.462945  [25600/50000]
# Training loop: loss: 1.533008  [32000/50000]
# Training loop: loss: 1.602417  [38400/50000]
# Training loop: loss: 1.430129  [44800/50000]
# Training Accuracy: 50.0%
# Testing Accuracy: 48.9%, Avg loss: 1.450321
#
# Epoch 14
# -------------------------------
# Training loop: loss: 1.426524  [    0/50000]
# Training loop: loss: 1.437310  [ 6400/50000]
# Training loop: loss: 1.223376  [12800/50000]
# Training loop: loss: 1.520074  [19200/50000]
# Training loop: loss: 1.435812  [25600/50000]
# Training loop: loss: 1.514317  [32000/50000]
# Training loop: loss: 1.579166  [38400/50000]
# Training loop: loss: 1.418912  [44800/50000]
# Training Accuracy: 50.7%
# Testing Accuracy: 49.5%, Avg loss: 1.434758
#
# Epoch 15
# -------------------------------
# Training loop: loss: 1.401686  [    0/50000]
# Training loop: loss: 1.419150  [ 6400/50000]
# Training loop: loss: 1.218760  [12800/50000]
# Training loop: loss: 1.505936  [19200/50000]
# Training loop: loss: 1.409052  [25600/50000]
# Training loop: loss: 1.495000  [32000/50000]
# Training loop: loss: 1.560189  [38400/50000]
# Training loop: loss: 1.406437  [44800/50000]
# Training Accuracy: 51.5%
# Testing Accuracy: 49.9%, Avg loss: 1.422126
#
# Epoch 16
# -------------------------------
# Training loop: loss: 1.375967  [    0/50000]
# Training loop: loss: 1.406272  [ 6400/50000]
# Training loop: loss: 1.210794  [12800/50000]
# Training loop: loss: 1.498616  [19200/50000]
# Training loop: loss: 1.385959  [25600/50000]
# Training loop: loss: 1.475947  [32000/50000]
# Training loop: loss: 1.544360  [38400/50000]
# Training loop: loss: 1.391079  [44800/50000]
# Training Accuracy: 52.2%
# Testing Accuracy: 50.3%, Avg loss: 1.407409
#
# Epoch 17
# -------------------------------
# Training loop: loss: 1.351839  [    0/50000]
# Training loop: loss: 1.391448  [ 6400/50000]
# Training loop: loss: 1.197580  [12800/50000]
# Training loop: loss: 1.479090  [19200/50000]
# Training loop: loss: 1.357510  [25600/50000]
# Training loop: loss: 1.463464  [32000/50000]
# Training loop: loss: 1.526149  [38400/50000]
# Training loop: loss: 1.379940  [44800/50000]
# Training Accuracy: 52.8%
# Testing Accuracy: 50.7%, Avg loss: 1.395304
#
# Epoch 18
# -------------------------------
# Training loop: loss: 1.332501  [    0/50000]
# Training loop: loss: 1.376643  [ 6400/50000]
# Training loop: loss: 1.187400  [12800/50000]
# Training loop: loss: 1.465504  [19200/50000]
# Training loop: loss: 1.339234  [25600/50000]
# Training loop: loss: 1.455469  [32000/50000]
# Training loop: loss: 1.506312  [38400/50000]
# Training loop: loss: 1.363243  [44800/50000]
# Training Accuracy: 53.3%
# Testing Accuracy: 51.3%, Avg loss: 1.382838
#
# Epoch 19
# -------------------------------
# Training loop: loss: 1.308980  [    0/50000]
# Training loop: loss: 1.363289  [ 6400/50000]
# Training loop: loss: 1.175925  [12800/50000]
# Training loop: loss: 1.454796  [19200/50000]
# Training loop: loss: 1.317369  [25600/50000]
# Training loop: loss: 1.443925  [32000/50000]
# Training loop: loss: 1.488010  [38400/50000]
# Training loop: loss: 1.350918  [44800/50000]
# Training Accuracy: 53.9%
# Testing Accuracy: 51.7%, Avg loss: 1.371815
#
# Epoch 20
# -------------------------------
# Training loop: loss: 1.290473  [    0/50000]
# Training loop: loss: 1.343377  [ 6400/50000]
# Training loop: loss: 1.165747  [12800/50000]
# Training loop: loss: 1.448059  [19200/50000]
# Training loop: loss: 1.296739  [25600/50000]
# Training loop: loss: 1.438635  [32000/50000]
# Training loop: loss: 1.469602  [38400/50000]
# Training loop: loss: 1.345091  [44800/50000]
# Training Accuracy: 54.5%
# Testing Accuracy: 51.9%, Avg loss: 1.363055
#
# Done!

# %% [markdown]
# ## <font size='5'>**III) Fine Tuning Hyperparameters**</font>

# %% [markdown]
# Adjusting the hyperparameters and gaining a deeper understanding of how they impact the ultimate performance is a substantial aspect of working with neural networks. Therefore, we encourage you to gain practical experience in this regard.

# %% [markdown]
# In this task, your goal is to play around with different settings for various options like layer size, batch size, learning rate. You should also experiment with optimizer hyperparameters including momentum, weight decay and more.
#
# To understand how these choices affect your model's performance, you'll create at least three graphs. Each graph will show how changing one of these options (except for epochs) impacts how well your model learns and predicts.

# %% [markdown]
# ## <font size='4'>**Example** - We've given you an example code for changing number of epochs so you can see how it's done.</font>

# %%
def test_hparams(
    learning_rate = 1e-3,
    batch_size = 64,
    epochs = 10,
    momentum = 0.9,
    weight_decay = 1e-3,
    dampening = 0.0,
    logging = False
):  
    if (logging==True):
        print("--------------------------------------------")
        print("Checking with hyperparameters:")
        print(f'''    learning_rate: {learning_rate}, 
    batch_size: {batch_size}, 
    epochs: {epochs}, 
    momentum: {momentum}, 
    weight_decay: {weight_decay}, 
    dampening: {dampening}''')
        print("--------------------------------------------")
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
        lr = learning_rate,
        momentum = momentum,
        weight_decay = weight_decay,
        dampening= dampening
    )
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)
    final_train_acc = 0
    final_training_loss = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(epochs):
        # print(f"Currently running epoch {t+1}")
        training_acc, training_loss = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=False)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=False)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
        final_training_loss = training_loss
    
    if (logging==True):
        print("--------------------------------------------")
        print(f"Final Training Accuracy: {final_train_acc}")
        print(f"Final Training Loss: {final_training_loss}")
        print(f"Final Testing Accuracy: {final_test_acc}")
        print(f"Final Testing Loss: {final_test_loss}")
        print("--------------------------------------------\n")
    return final_train_acc, final_training_loss, final_test_acc, final_test_loss

test_hparams(epochs=10, logging=True)
# Out:
# --------------------------------------------
# Checking with hyperparameters:
#     learning_rate: 0.001,
#     batch_size: 64,
#     epochs: 10,
#     momentum: 0.9,
#     weight_decay: 0.001,
#     dampening: 0.0
# --------------------------------------------
# --------------------------------------------
# Final Training Accuracy: 47.449999999999996
# Final Training Loss: 1.7807223796844482
# Final Testing Accuracy: 47.05
# Final Testing Loss: 1.5030451542252947
# --------------------------------------------
# (47.449999999999996, 1.7807223796844482, 47.05, 1.5030451542252947)

# %%
def visualize_hparam_effect(
    hparam_name, hparam_values,
    test_accs, test_losses, training_accs,
    hparam_scale = 'linear'
):
    fig, ax_loss = plt.subplots()
    ax_loss.plot(hparam_values,test_losses, color ='tab:red', label='testing loss')
    ax_loss.set_yscale('log')
    ax_loss.set_ylabel('Loss')

    ax_loss.set_xlabel(hparam_name.capitalize())
    ax_loss.set_xscale(hparam_scale)
    ax_loss.set_xticks(hparam_values)

    ax_acc = ax_loss.twinx()
    ax_acc.plot(hparam_values,training_accs, color ='tab:green', label='training accuracy')
    ax_acc.plot(hparam_values,test_accs, color ='tab:blue', label='testing accuracy')
    ax_acc.set_ylim([0,100])
    ax_acc.set_ylabel('Accuracy')

    fig.legend(loc = 'lower left', bbox_to_anchor=(0, 0))
    fig.tight_layout()

# %%
learning_rate = 1e-3
batch_size = 64
epochs = [1, 5, 10, 15, 20, 25]
momentum = 0.9
weight_decay = 1e-3
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for e in epochs: #Would change this to reflect whatever hyperparameter you would be testing
    print("testing with epoch: ", e)
    final_train_acc, final_train_loss, final_test_acc, final_test_loss = test_hparams(
        epochs=e, 
        learning_rate=learning_rate,
        batch_size=batch_size,
        momentum=momentum,
        weight_decay=weight_decay,
        dampening=dampening,
        logging=False
    )
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
print("Done!")

visualize_hparam_effect(
    hparam_name = 'epochs',
    hparam_values = epochs,
    test_accs = test_accs,
    test_losses = test_losses,
    training_accs = training_accs
)
# Out:
# testing with epoch:  1
# testing with epoch:  5
# testing with epoch:  10
# testing with epoch:  15
# testing with epoch:  20
# testing with epoch:  25
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.3 - Experiment 1 (2 point)</font>

# %% [markdown]
# I am tuning `learning_rate` hyperparameter for better performance

# %%
############################################################################
# TODO: Implement your code here
############################################################################
learning_rate = [1e-1, 1e-3, 1e-5, 1e-7][::-1]
batch_size = 64
epochs = 15
momentum = 0.9
weight_decay = 1e-3
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for lr in learning_rate: #Would change this to reflect whatever hyperparameter you would be testing
    print("testing with learning_rate: ", lr)
    final_train_acc, final_train_loss, final_test_acc, final_test_loss = test_hparams(
        epochs=epochs, 
        learning_rate=lr,
        batch_size=batch_size,
        momentum=momentum,
        weight_decay=weight_decay,
        dampening=dampening,
        logging=False
    )
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
print("Done!")

visualize_hparam_effect(
    hparam_name = 'learning rate',
    hparam_values = learning_rate,
    test_accs = test_accs,
    test_losses = test_losses,
    training_accs = training_accs,
    hparam_scale = 'log',
)
############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# testing with learning_rate:  1e-07
# testing with learning_rate:  1e-05
# testing with learning_rate:  0.001
# testing with learning_rate:  0.1
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.3 - Experiment 2 (2 point)</font>

# %% [markdown]
# I am tuning `momentum` hyperparameter for better performance

# %%
############################################################################
# TODO: Implement your code here
############################################################################
learning_rate = 1e-3
batch_size = 64
epochs = 20
momentum = [0, 0.1, 0.3, 0.5, 0.7, 0.9, 0.99]
weight_decay = 1e-3
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for m in momentum: #Would change this to reflect whatever hyperparameter you would be testing
    print("testing with momentum: ", m)
    final_train_acc, final_train_loss, final_test_acc, final_test_loss = test_hparams(
        epochs=epochs, 
        learning_rate=learning_rate,
        batch_size=batch_size,
        momentum=m,
        weight_decay=weight_decay,
        dampening=dampening,
        logging=False
    )
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
print("Done!")

visualize_hparam_effect(
    hparam_name = 'momentum',
    hparam_values = momentum,
    test_accs = test_accs,
    test_losses = test_losses,
    training_accs = training_accs,
    hparam_scale = 'linear',
)
############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# testing with momentum:  0
# testing with momentum:  0.1
# testing with momentum:  0.3
# testing with momentum:  0.5
# testing with momentum:  0.7
# testing with momentum:  0.9
# testing with momentum:  0.99
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.4 - Experiment 3 (2 point)</font>

# %% [markdown]
# I am tuning `weight_decay` hyperparameter for better performance

# %%
############################################################################
# TODO: Implement your code here
############################################################################
learning_rate = 1e-3
batch_size = 64
epochs = 20
momentum = 0.9
weight_decay = [0.9, 0.5, 0.3, 1e-1, 1e-3, 1e-5, 0][::-1]
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for wd in weight_decay: #Would change this to reflect whatever hyperparameter you would be testing
    print("testing with weight decay: ", wd)
    final_train_acc, final_train_loss, final_test_acc, final_test_loss = test_hparams(
        epochs=epochs, 
        learning_rate=learning_rate,
        batch_size=batch_size,
        momentum=momentum,
        weight_decay=wd,
        dampening=dampening,
        logging=False
    )
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
print("Done!")

visualize_hparam_effect(
    hparam_name = 'weight decay',
    hparam_values = weight_decay,
    test_accs = test_accs,
    test_losses = test_losses,
    training_accs = training_accs,
    hparam_scale = 'log',
)

############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# testing with weight decay:  0
# testing with weight decay:  1e-05
# testing with weight decay:  0.001
# testing with weight decay:  0.1
# testing with weight decay:  0.3
# testing with weight decay:  0.5
# testing with weight decay:  0.9
# Done!

# %%
learning_rate = 1e-3
batch_size = 64
epochs = 15
momentum = 0.9
weight_decay = 1e-3
dampening = [0.9, 0.5, 0.3, 1e-1, 1e-3, 1e-5, 0][::-1]

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for dmp in dampening: #Would change this to reflect whatever hyperparameter you would be testing
    print("testing with dampening: ", dmp)
    final_train_acc, final_train_loss, final_test_acc, final_test_loss = test_hparams(
        epochs=epochs, 
        learning_rate=learning_rate,
        batch_size=batch_size,
        momentum=momentum,
        weight_decay=weight_decay,
        dampening=dmp,
        logging=False
    )
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
print("Done!")

visualize_hparam_effect(
    hparam_name = 'dampening',
    hparam_values = dampening,
    test_accs = test_accs,
    test_losses = test_losses,
    training_accs = training_accs,
    hparam_scale = 'log',
)
# Out:
# testing with dampening:  0
# testing with dampening:  1e-05
# testing with dampening:  0.001
# testing with dampening:  0.1
# testing with dampening:  0.3
# testing with dampening:  0.5
# testing with dampening:  0.9
# Done!
